# %% [markdown]
# # Homework 3: Mining Data Streams
# #### Authors: Sherly Sherly and Anna Martignano

# %% [markdown]
# ## Task
# You are to study and implement a streaming graph processing algorithm described in one of the above papers of your choice. In order to accomplished your task, you are to perform the following two steps
#
# 1. Implement the reservoir sampling or the Flajolet-Martin algorithm used in the graph algorithm presented in the paper you have selected;
# 2. Implement the streaming graph algorithm presented in the paper that make use of the algorithm implemented in the first step.

# %% [markdown]
# ## Reservoir sampling in TRIEST-BASE
# The trièst-base algorithm uses standard reservoir sampling to maintain the edge sample S:
# - If t ≤ M, then the edge et = (u, v) on the stream at time t is deterministically inserted in S.
# - If t > M, trièst-base flips a biased coin with heads probability M/t. If the outcome is heads, it chooses an edge (w, z) ∈ S uniformly at random, removes (w, z) from S, and inserts (u, v) in S. Otherwise, S is not modified.
#
#         Input: Insertion-only edge stream Σ, integer M ≥ 6
#         S ← ∅, t ← 0, τ ← 0
#         for each element (+, (u, v)) from Σ do
#             t ← t + 1
#             if SampleEdge((u, v), t) then
#                 S ← S ∪ {(u, v)}
#                 UpdateCounters(+, (u, v))
#
#         function SampleEdge((u, v), t)
#             if t ≤ M then
#                 return True
#             else if FlipBiasedCoin(M/t) = heads then
#                 (u', v') ← random edge from S
#                 S ← S \ {(u', v')}
#                 UpdateCounters(−, (u',v'))
#                 return True
#             return False
#
#         function UpdateCounters((•, (u, v)))
#             NSu,v ← NSu ∩ NSv
#             for all c ∈ NSu,v do
#                 τ ← τ • 1
#                 τc ← τc • 1
#                 τu ← τu • 1
#                 τv ← τv • 1

# %%
from collections import defaultdict
import random
import operator

class Graph:
    def __init__(self, M):
        self.M = M
        self.t = 0
        self.sampleSet = set()
        self.dictNeighbor = {}
        self.tau = defaultdict(lambda:0)
        self.TAU = 0
        
        
    def addEdge(self, u, v):
        self.sampleSet.add((u,v))
            
        if u in self.dictNeighbor.keys():
            self.dictNeighbor[u].add(v)
        else:
            self.dictNeighbor[u] = set([v])

        if v in self.dictNeighbor.keys():
            self.dictNeighbor[v].add(u)
        else:
            self.dictNeighbor[v] = set([u])
    
    def removeEdge(self, w, x):
        self.sampleSet.remove((w,x))
            
        self.dictNeighbor[w].remove(x)
        self.dictNeighbor[x].remove(w)
            
        if(len(self.dictNeighbor[w]) == 0):
            del self.dictNeighbor[w]
        if(len(self.dictNeighbor[x]) == 0):
            del self.dictNeighbor[x]
                
    def sampleEdge(self):
        if(self.t <= self.M):
            return True
        else:
            flipCoin = random.random()
            if(flipCoin < self.M/float(self.t)):
                edge = random.choice(tuple(self.sampleSet))
                w = int(edge[0])
                x = int(edge[1])
                self.removeEdge(w,x)
                self.updateCounters("-",w,x)
                return True
        return False
    
    def updateCounters(self,operation,u,v):
        if(u in self.dictNeighbor.keys() and v in self.dictNeighbor.keys()):
            NSu = self.dictNeighbor[u]
            NSv = self.dictNeighbor[v]

            NSuv = NSu & NSv

            ops = { "+": operator.add, "-": operator.sub }        
            if(len(NSuv) > 0):
                for c in NSuv:
                    self.tau[c] = ops[operation](self.tau[c],1)
                    self.tau[u] = ops[operation](self.tau[u],1)
                    self.tau[v] = ops[operation](self.tau[v],1)
                    self.TAU = ops[operation](self.TAU,1)
                
    def launchTriest(self,filepath):
        file = open(filepath,'r')
        for line in file:
            input = line.split()
            u = int(min(input))
            v = int(max(input))
            self.t += 1
            
            if((u,v) in self.sampleSet or u == v):
                continue
            
            if(self.sampleEdge()):
                self.addEdge(u,v)
                self.updateCounters("+",u,v)
            
            if(self.t%10000==0):
                print("Iteration {}|Global TAU {}|Samples {}".format(self.t,self.TAU,len(self.sampleSet)))
        file.close()

# %%
triestBase = Graph(10000)
triestBase.launchTriest('com-amazon.tar/com-amazon.tar')
# Out:
# Iteration 10000|Global TAU 3009|Samples 10000
# Iteration 20000|Global TAU 817|Samples 10000
# Iteration 30000|Global TAU 386|Samples 10000
# Iteration 40000|Global TAU 226|Samples 10000
# Iteration 50000|Global TAU 138|Samples 10000
# Iteration 60000|Global TAU 100|Samples 10000
# Iteration 70000|Global TAU 76|Samples 10000
# Iteration 80000|Global TAU 54|Samples 10000
# Iteration 90000|Global TAU 48|Samples 10000
# Iteration 100000|Global TAU 37|Samples 10000
# Iteration 110000|Global TAU 31|Samples 10000
# Iteration 120000|Global TAU 25|Samples 10000
# Iteration 130000|Global TAU 21|Samples 10000
# Iteration 140000|Global TAU 22|Samples 10000
# Iteration 150000|Global TAU 27|Samples 10000
# Iteration 160000|Global TAU 19|Samples 10000
# Iteration 170000|Global TAU 18|Samples 10000
# Iteration 180000|Global TAU 15|Samples 10000
# Iteration 190000|Global TAU 10|Samples 10000
# Iteration 200000|Global TAU 10|Samples 10000
# Iteration 210000|Global TAU 11|Samples 10000
# Iteration 220000|Global TAU 9|Samples 10000
# Iteration 230000|Global TAU 8|Samples 10000
# Iteration 240000|Global TAU 7|Samples 10000
# Iteration 250000|Global TAU 6|Samples 10000
# Iteration 260000|Global TAU 7|Samples 10000
# Iteration 270000|Global TAU 6|Samples 10000
# Iteration 280000|Global TAU 7|Samples 10000
# Iteration 290000|Global TAU 6|Samples 10000
# Iteration 300000|Global TAU 4|Samples 10000
# Iteration 310000|Global TAU 5|Samples 10000
# Iteration 320000|Global TAU 4|Samples 10000
# Iteration 330000|Global TAU 4|Samples 10000
# Iteration 340000|Global TAU 4|Samples 10000
# Iteration 350000|Global TAU 4|Samples 10000
# Iteration 360000|Global TAU 5|Samples 10000
# Iteration 370000|Global TAU 5|Samples 10000
# Iteration 380000|Global TAU 4|Samples 10000
# Iteration 390000|Global TAU 3|Samples 10000
# Iteration 400000|Global TAU 3|Samples 10000
# Iteration 410000|Global TAU 3|Samples 10000
# Iteration 420000|Global TAU 1|Samples 10000
# Iteration 430000|Global TAU 1|Samples 10000
# Iteration 440000|Global TAU 1|Samples 10000
# Iteration 450000|Global TAU 1|Samples 10000
# Iteration 460000|Global TAU 1|Samples 10000
# Iteration 470000|Global TAU 2|Samples 10000
# Iteration 480000|Global TAU 2|Samples 10000
# Iteration 490000|Global TAU 2|Samples 10000
# Iteration 500000|Global TAU 2|Samples 10000
# Iteration 510000|Global TAU 2|Samples 10000
# Iteration 520000|Global TAU 3|Samples 10000
# Iteration 530000|Global TAU 3|Samples 10000
# Iteration 540000|Global TAU 4|Samples 10000
# Iteration 550000|Global TAU 3|Samples 10000
# Iteration 560000|Global TAU 3|Samples 10000
# Iteration 570000|Global TAU 3|Samples 10000
# Iteration 580000|Global TAU 3|Samples 10000
# Iteration 590000|Global TAU 3|Samples 10000
# Iteration 600000|Global TAU 3|Samples 10000
# Iteration 610000|Global TAU 3|Samples 10000
# Iteration 620000|Global TAU 2|Samples 10000
# Iteration 630000|Global TAU 1|Samples 10000
# Iteration 640000|Global TAU 0|Samples 10000
# Iteration 650000|Global TAU 0|Samples 10000
# Iteration 660000|Global TAU 0|Samples 10000
# Iteration 670000|Global TAU 0|Samples 10000
# Iteration 680000|Global TAU 0|Samples 10000
# Iteration 690000|Global TAU 0|Samples 10000
# Iteration 700000|Global TAU 0|Samples 10000
# Iteration 710000|Global TAU 0|Samples 10000
# Iteration 720000|Global TAU 0|Samples 10000
# Iteration 730000|Global TAU 1|Samples 10000
# Iteration 740000|Global TAU 1|Samples 10000
# Iteration 750000|Global TAU 1|Samples 10000
# Iteration 760000|Global TAU 1|Samples 10000
# Iteration 770000|Global TAU 1|Samples 10000
# Iteration 780000|Global TAU 1|Samples 10000
# Iteration 790000|Global TAU 0|Samples 10000
# Iteration 800000|Global TAU 0|Samples 10000
# Iteration 810000|Global TAU 0|Samples 10000
# Iteration 820000|Global TAU 0|Samples 10000
# Iteration 830000|Global TAU 0|Samples 10000
# Iteration 840000|Global TAU 0|Samples 10000
# Iteration 850000|Global TAU 0|Samples 10000
# Iteration 860000|Global TAU 0|Samples 10000
# Iteration 870000|Global TAU 0|Samples 10000
# Iteration 880000|Global TAU 0|Samples 10000
# Iteration 890000|Global TAU 0|Samples 10000
# Iteration 900000|Global TAU 0|Samples 10000
# Iteration 910000|Global TAU 0|Samples 10000
# Iteration 920000|Global TAU 0|Samples 10000

# %% [markdown]
# ## Reservoir sampling in TRIEST-IMPR
#         Input: Insertion-only edge stream Σ, integer M ≥ 6
#         S ← ∅, t ← 0, τ ← 0
#         for each element (+, (u, v)) from Σ do
#             t ← t + 1
#             UpdateCounters((u, v))
#             if SampleEdge((u, v), t) then
#                 S ← S ∪ {(u, v)}
#
#         function SampleEdge((u, v), t)
#             if t ≤ M then
#                 return True
#             else if FlipBiasedCoin(M/t) = heads then
#                 (u', v') ← random edge from S
#                 S ← S \ {(u', v')}
#                 return True
#             return False
#
#         function UpdateCounters((u, v))
#             NSu,v ← NSu ∩ NSv
#             η(t) = max{1,(t − 1)(t − 2)/(M(M − 1))}
#             for all c ∈ NSu,v do
#                 τ ← τ + η(t)
#                 τc ← τc + η(t)
#                 τu ← τu + η(t)
#                 τv ← τv + η(t)

# %%
from collections import defaultdict
import random
import operator

class GraphImpr:
    def __init__(self, M):
        self.M = M
        self.t = 0
        self.sampleSet = set()
        self.dictNeighbor = {}
        self.tau = defaultdict(lambda:0)
        self.TAU = 0
        
        
    def addEdge(self, u, v):
        self.sampleSet.add((u,v))
            
        if u in self.dictNeighbor.keys():
            self.dictNeighbor[u].add(v)
        else:
            self.dictNeighbor[u] = set([v])

        if v in self.dictNeighbor.keys():
            self.dictNeighbor[v].add(u)
        else:
            self.dictNeighbor[v] = set([u])
    
    def removeEdge(self, w, x):
        self.sampleSet.remove((w,x))
            
        self.dictNeighbor[w].remove(x)
        self.dictNeighbor[x].remove(w)
            
        if(len(self.dictNeighbor[w]) == 0):
            del self.dictNeighbor[w]
        if(len(self.dictNeighbor[x]) == 0):
            del self.dictNeighbor[x]
                
    def sampleEdge(self):
        if(self.t <= self.M):
            return True
        else:
            flipCoin = random.random()
            if(flipCoin < self.M/float(self.t)):
                edge = random.choice(tuple(self.sampleSet))
                w = int(edge[0])
                x = int(edge[1])
                self.removeEdge(w,x)
                return True
        return False
    
    def updateCounters(self,u,v):
        if(u in self.dictNeighbor.keys() and v in self.dictNeighbor.keys()):
            NSu = self.dictNeighbor[u]
            NSv = self.dictNeighbor[v]

            NSuv = NSu & NSv
            
            eta = max(1, ((self.t-1)*(self.t-2)/(self.M*(self.M-1))) )
      
            if(len(NSuv) > 0):
                for c in NSuv:
                    self.tau[c] += eta
                    self.tau[u] += eta
                    self.tau[v] += eta
                    self.TAU += eta
                
    def launchTriest(self,filepath):
        file = open(filepath,'r')
        for line in file:
            input = line.split()
            u = int(min(input))
            v = int(max(input))
            self.t += 1
            
            if((u,v) in self.sampleSet or u == v):
                continue
            
            self.updateCounters(u,v)
            
            if(self.sampleEdge()):
                self.addEdge(u,v)
            
            if(self.t%10000==0):
                print("Iteration {}|Global TAU {}|Samples {}".format(self.t,self.TAU,len(self.sampleSet)))
        file.close()

# %%
triestImpr = GraphImpr(10000)
triestImpr.launchTriest('com-amazon.tar/com-amazon.tar')
# Out:
# Iteration 10000|Global TAU 3009|Samples 10000
# Iteration 20000|Global TAU 6646.67917505751|Samples 10000
# Iteration 30000|Global TAU 11096.906209400924|Samples 10000
# Iteration 40000|Global TAU 15322.554175977573|Samples 10000
# Iteration 50000|Global TAU 19417.550387158688|Samples 10000
# Iteration 60000|Global TAU 23382.822722392208|Samples 10000
# Iteration 70000|Global TAU 27307.762178417797|Samples 10000
# Iteration 80000|Global TAU 32237.287185438483|Samples 10000
# Iteration 90000|Global TAU 37504.873246724615|Samples 10000
# Iteration 100000|Global TAU 41985.278543814326|Samples 10000
# Iteration 110000|Global TAU 45603.18430481044|Samples 10000
# Iteration 120000|Global TAU 50420.0918366236|Samples 10000
# Iteration 130000|Global TAU 57186.64961506144|Samples 10000
# Iteration 140000|Global TAU 63064.60339709963|Samples 10000
# Iteration 150000|Global TAU 66852.95246722664|Samples 10000
# Iteration 160000|Global TAU 72157.58860224014|Samples 10000
# Iteration 170000|Global TAU 76827.09838233818|Samples 10000
# Iteration 180000|Global TAU 81064.56260037996|Samples 10000
# Iteration 190000|Global TAU 84900.72500468037|Samples 10000
# Iteration 200000|Global TAU 89069.97492529244|Samples 10000
# Iteration 210000|Global TAU 95852.63147698759|Samples 10000
# Iteration 220000|Global TAU 103710.50371827172|Samples 10000
# Iteration 230000|Global TAU 108784.82285396528|Samples 10000
# Iteration 240000|Global TAU 114887.81291513139|Samples 10000
# Iteration 250000|Global TAU 125230.03225256514|Samples 10000
# Iteration 260000|Global TAU 129714.5028760675|Samples 10000
# Iteration 270000|Global TAU 136675.49885098496|Samples 10000
# Iteration 280000|Global TAU 141917.80614769465|Samples 10000
# Iteration 290000|Global TAU 144372.4996154014|Samples 10000
# Iteration 300000|Global TAU 149523.91941154102|Samples 10000
# Iteration 310000|Global TAU 154131.3806052004|Samples 10000
# Iteration 320000|Global TAU 161078.1301102509|Samples 10000
# Iteration 330000|Global TAU 165236.8390252624|Samples 10000
# Iteration 340000|Global TAU 174247.44263652354|Samples 10000
# Iteration 350000|Global TAU 182544.81499423934|Samples 10000
# Iteration 360000|Global TAU 195142.1305129312|Samples 10000
# Iteration 370000|Global TAU 202995.371810641|Samples 10000
# Iteration 380000|Global TAU 208556.69987640757|Samples 10000
# Iteration 390000|Global TAU 215965.27726600654|Samples 10000
# Iteration 400000|Global TAU 219026.78022342228|Samples 10000
# Iteration 410000|Global TAU 233807.01319699961|Samples 10000
# Iteration 420000|Global TAU 242385.34816047602|Samples 10000
# Iteration 430000|Global TAU 249686.66904830482|Samples 10000
# Iteration 440000|Global TAU 261024.8815370737|Samples 10000
# Iteration 450000|Global TAU 266921.9146427843|Samples 10000
# Iteration 460000|Global TAU 268962.66895721573|Samples 10000
# Iteration 470000|Global TAU 275437.88600286026|Samples 10000
# Iteration 480000|Global TAU 279956.34194077406|Samples 10000
# Iteration 490000|Global TAU 287023.3525433743|Samples 10000
# Iteration 500000|Global TAU 294380.1864218621|Samples 10000
# Iteration 510000|Global TAU 299492.47082758264|Samples 10000
# Iteration 520000|Global TAU 310099.8686046003|Samples 10000
# Iteration 530000|Global TAU 321183.08098219807|Samples 10000
# Iteration 540000|Global TAU 324062.8557823981|Samples 10000
# Iteration 550000|Global TAU 329940.23543102294|Samples 10000
# Iteration 560000|Global TAU 342273.1689535752|Samples 10000
# Iteration 570000|Global TAU 351833.66983102297|Samples 10000
# Iteration 580000|Global TAU 371495.7073919191|Samples 10000
# Iteration 590000|Global TAU 374941.019950995|Samples 10000
# Iteration 600000|Global TAU 378484.9630821081|Samples 10000
# Iteration 610000|Global TAU 385822.5378890088|Samples 10000
# Iteration 620000|Global TAU 389613.073820662|Samples 10000
# Iteration 630000|Global TAU 405148.1140287428|Samples 10000
# Iteration 640000|Global TAU 429373.12987812783|Samples 10000
# Iteration 650000|Global TAU 433541.5467758176|Samples 10000
# Iteration 660000|Global TAU 437792.7576207021|Samples 10000
# Iteration 670000|Global TAU 442268.1127337734|Samples 10000
# Iteration 680000|Global TAU 451391.59667006705|Samples 10000
# Iteration 690000|Global TAU 470109.66508670873|Samples 10000
# Iteration 700000|Global TAU 494292.58719473955|Samples 10000
# Iteration 710000|Global TAU 499249.2217382139|Samples 10000
# Iteration 720000|Global TAU 509382.8282109012|Samples 10000
# Iteration 730000|Global TAU 509382.8282109012|Samples 10000
# Iteration 740000|Global TAU 509382.8282109012|Samples 10000
# Iteration 750000|Global TAU 509382.8282109012|Samples 10000
# Iteration 760000|Global TAU 532177.574468047|Samples 10000
# Iteration 770000|Global TAU 561441.0477234125|Samples 10000
# Iteration 780000|Global TAU 573315.3011950197|Samples 10000
# Iteration 790000|Global TAU 585616.9241831986|Samples 10000
# Iteration 800000|Global TAU 604491.1289104713|Samples 10000
# Iteration 810000|Global TAU 604491.1289104713|Samples 10000
# Iteration 820000|Global TAU 624590.599176118|Samples 10000
# Iteration 830000|Global TAU 631340.0198437448|Samples 10000
# Iteration 840000|Global TAU 645290.4710576262|Samples 10000
# Iteration 850000|Global TAU 666714.3238575262|Samples 10000
# Iteration 860000|Global TAU 688566.1646713676|Samples 10000
# Iteration 870000|Global TAU 696082.8440001005|Samples 10000
# Iteration 880000|Global TAU 719061.0958075613|Samples 10000
# Iteration 890000|Global TAU 719061.0958075613|Samples 10000
# Iteration 900000|Global TAU 734980.6637766382|Samples 10000
# Iteration 910000|Global TAU 734980.6637766382|Samples 10000
# Iteration 920000|Global TAU 751767.6079675973|Samples 10000
